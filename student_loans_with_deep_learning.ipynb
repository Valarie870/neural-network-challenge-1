# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# credit_ranking
# 1    855
# 0    744
# Name: count, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df['credit_ranking']

# Display a sample of y
print(y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop('credit_ranking', axis=1)

# Review the features DataFrame
print(X.head())
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Check the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1279, 11)
# X_test shape: (320, 11)
# y_train shape: (1279,)
# y_test shape: (320,)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
X_scaler = StandardScaler()


# Fit the scaler to the features training dataset
X_train_scaled = X_scaler.fit_transform(X_train)

# Fit the scaler to the features training dataset - #testing
X_test_scaled = X_scaler.transform(X_test)

# Check the shape of the scaled training dataset
print("X_train_scaled shape:", X_train_scaled.shape)
# Out:
# X_train_scaled shape: (1279, 11)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
input_dim = X_train_scaled.shape[1]

# Review the number of features
print("Number of input features:", input_dim)
# Out:
# Number of input features: 11

# %%
# Define the number of hidden nodes for the first hidden layer -- use shape?
hidden_layer1 = 64

# Define the number of hidden nodes for the second hidden layer
hidden_layer2 = 32

# Define the number of neurons in the output layer
output_layer = 1

# %%
# Create the Sequential model instance
nn_model = tf.keras.models.Sequential()

#Set the input nodes to the number of features
input_nodes = len(X.columns)

# Add the first hidden layer
nn_model.add(tf.keras.layers.Dense(units=64, activation="relu", input_dim=input_nodes))

# Add the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=32, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Display the Sequential model summary
nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# Fit the model using 50 epochs and the training data
history = nn_model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.5046 - loss: 3.2012 - val_accuracy: 0.6094 - val_loss: 0.6949
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6314 - loss: 0.6551 - val_accuracy: 0.6250 - val_loss: 0.6404
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6400 - loss: 0.6370 - val_accuracy: 0.6250 - val_loss: 0.6369
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6211 - loss: 0.6498 - val_accuracy: 0.6211 - val_loss: 0.6420
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5973 - loss: 0.6613 - val_accuracy: 0.6250 - val_loss: 0.6377
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6258 - loss: 0.6304 - val_accuracy: 0.6406 - val_loss: 0.6469
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6237 - loss: 0.6509 - val_accuracy: 0.6328 - val_loss: 0.6357
# Epoch 8/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
eval_loss, eval_accuracy = nn_model.evaluate(X_test, y_test, verbose=0)

# Display the model loss and accuracy results
print(f"Test Loss: {eval_loss:.4f}")
print(f"Test Accuracy: {eval_accuracy:.4f}")
# Out:
# Test Loss: 0.5524
# Test Accuracy: 0.7188

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Save the file to your Drive
nn_model.save('/content/drive/My Drive/Colab Notebooks/neural network challenge 1 - Mod 18/student_loans.keras')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
from tensorflow.keras.models import load_model


# Set the model's file path
nn_model.save('/content/drive/My Drive/Colab Notebooks/neural network challenge 1 - Mod 18/student_loans.keras')

# Load the model to a new object
new_model = load_model('/content/drive/My Drive/Colab Notebooks/neural network challenge 1 - Mod 18/student_loans.keras')

nn_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,645 (33.77 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,764 (22.52 KB)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_model.predict(X_test_scaled,verbose=2)


# Display a sample of the predictions
predictions
# Out:
# 10/10 - 0s - 10ms/step
# array([[0.554427  ],
#        [0.26688644],
#        [0.80368865],
#        [0.418999  ],
#        [0.59649223],
#        [0.65076   ],
#        [0.83299357],
#        [0.20553765],
#        [0.14566532],
#        [0.09386639],
#        [0.28819773],
#        [0.31530133],
#        [0.48882017],
#        [0.87314206],
#        [0.23868065],
#        [0.41685078],
#        [0.2113476 ],
#        [0.29083768],
#        [0.5494099 ],
#        [0.17825411],
#        [0.5404766 ],
#        [0.7667378 ],
#        [0.42690942],
#        [0.90249807],
#        [0.64194596],
#        [0.36013287],
#        [0.8046155 ],
#        [0.48693076],
#        [0.36352542],
#        [0.9761706 ],
#        [0.05920647],
#        [0.8073936 ],
#        [0.19036251],
#        [0.7323132 ],
#        [0.16423248],
#        [0.50059956],
#        [0.3820212 ],
#        [0.23951606],
#        [0.46955985],
#        [0.15343824],
#        [0.65842956],
#        [0.32519823],
# ...

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data=predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df
# Out:
#      predictions
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            1.0
# ..           ...
# 315          1.0
# 316          0.0
# 317          0.0
# 318          1.0
# 319          1.0
#
# [320 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
#Import the LabelEncoder class from the sklearn.preprocessing module
from sklearn.preprocessing import LabelEncoder

#Encode the y data with the label encoder
#Create instance of label encoder
le = LabelEncoder()

# Fit and transform the y training and testing data using the label encoder
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# Print the classification report with the y test data and predictions
print(classification_report(y_test_encoded, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.82      0.71       154
#            1       0.77      0.56      0.65       166
#
#     accuracy                           0.68       320
#    macro avg       0.70      0.69      0.68       320
# weighted avg       0.70      0.68      0.68       320

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# Response: Data needed to collect would consist of demographics such as age, residency status (domestic or international), education including degree type (undergrad/bachelor or graduate/master), field of study (engineering, education, humanities), current education status (freshman, senior), anticipated graduation date, financial information (household income, employment status if possible, existing debt), credit score, and desired loan amount.
#
# This data would be relevant because these attributes factor into the likelihood of a loan repayment and how you could strucuture the terms. For example, someone who is a freshman would likely not start repaying until after graduation, whereas someone who is a senior would likely be able to start repayment quicker. Also, field of study can be taken into account as some fields such as engineering may offer more job opportunities or higher earning potential compared to jobs in art history.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# Response: My model would use Content-based filtering because it would focus on matching a user's/student's attributes with loan options. This would enable the different attributes (features) to personalize recommendations. Also, loan specific items such as interest rates, repayment terms, can be matched to the student's needs/profile. This would allow for a more personalized experienced that would lead to better engagement and more likelihood of repayment because you would have direct correlation of attributes between loan offerings and student profiles.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Response: One real-world challenge to take into consideration would be bias, as models can "expand" on biases in training data, and the biases can lead to discrimination in loan offerings. This could lead to students from lower income households being offered higher interest rates compared to those from other households.
#
# Another real-world challenge would be market conditions, as interest rates fluctuate and government regulations change, impacting the Federal Reserve Rate, which impacts interest rates overall. If data is not current, loan options may not align to current conditions or interest rates. This could be misleading for students as they think they are getting one rate, but then end up with another. This could also affect the organization as students and others may not be able to put their "trust" in the organization.
